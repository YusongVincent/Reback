# %% [markdown]
# graphviz

# %%
import graphviz

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ** keras 还没安装 **

# %%
import numpy as np
import scipy
import pandas as pd
import sklearn
import keras.backend as K
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-58de0c3f4f62> in <module>()
#       3 import pandas as pd
#       4 import sklearn
# ----> 5 import keras.backend as K
#       6 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'keras'

# %%
A=np.array([0,3,5])
B=np.array([5,3,0])
print("A+B=",np.add(A,B))
print("A-B=",np.subtract(A,B,B))
# Out:
# A+B= [5 6 5]
# A-B= [-5  0  5]

# %%
C=np.array([[1,2,3]])
D=np.array([[1],
           [2],
           [3]])
print("C dot D=",np.dot(C,D))
# Out:
# C dot D= [[14]]

# %%
C.shape
# Out:
# (1, 3)

# %%
C*D
print(C*C)
# Out:
# [[1 4 9]]

# %%
np.matmul(C,D)
# Out:
# array([[14]])

# %%
import sklearn

# %% [markdown]
# # 标题
# ## 标题
#
# **黑体**
#
# *斜体*
#
# >引用一段话
#
# * 列出不带编号的观点
#     * 哈哈哈哈
#         * 哎
#
#
# 1. 你是猪
#     1. 你才是猪头
#     2. 你也是猪头
# 2. 我们都是猪

# %% [markdown]
# $\sum_{i=1}^{i=N}x_i$
#
# $e^{i\pi}+1=0$

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1524943853152&di=c9eaf205f8d377868abcdb7cd5a0b83f&imgtype=0&src=http%3A%2F%2Fimage13.m1905.cn%2Fuploadfile%2F2016%2F0319%2F20160319090040492.jpg)
# <img src='https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1524943853152&di=c9eaf205f8d377868abcdb7cd5a0b83f&imgtype=0&src=http%3A%2F%2Fimage13.m1905.cn%2Fuploadfile%2F2016%2F0319%2F20160319090040492.jpg',width=300>

# %% [markdown]
# |你|我|他|
# |:----:|---:|:----|
# |傻|聪明|傻|
# |你很傻|外婆也不聪明|她超杀|
